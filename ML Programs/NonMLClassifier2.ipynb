# %%
import pandas as pd

# %%
path = '../Allwords.csv'
pd1 = pd.read_csv(path)
pd1.head()
# Out:
#      Negative   Positive
# 0     2-faced         a+
# 1     2-faces     abound
# 2    abnormal    abounds
# 3     abolish  abundance
# 4  abominable   abundant

# %%
pd2 = pd1.set_index('Negative')
pd2 = pd2.drop('Positive', axis=1)
pd3 = pd1.set_index('Positive')
pd3 = pd3.drop('Negative', axis=1)
pd3.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [a+, abound, abounds, abundance, abundant]

# %%
def sentScore(split_text):
    posCount = 0
    negCount = 0
    posArray = []
    negArray = []
    for x in split_text:
        try:
            posArray.append(pd3.loc[x])
        except KeyError:
            pass
        try:
            negArray.append(pd2.loc[x])
        except KeyError:
            pass
    posCount = len(posArray)
    negCount = len(negArray)
#     print(posArray)
#     print(negArray)
    return((posCount - negCount)/len(split_text)) #, posCount, negCount)

# %%
path2 = '../Datafiniti_Hotel_Reviews.csv'

# %%
df2 = pd.read_csv(path2)

# %%
df2.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVwc252WIN2L1WUfpqLP  2016-10-30T21:42:42Z  2018-09-10T21:06:27Z
# 1  AVwc252WIN2L1WUfpqLP  2016-10-30T21:42:42Z  2018-09-10T21:06:27Z
# 2  AVwc252WIN2L1WUfpqLP  2016-10-30T21:42:42Z  2018-09-10T21:06:27Z
# 3  AVwdOclqIN2L1WUfti38  2015-11-28T19:19:35Z  2018-09-10T21:06:16Z
# 4  AVwdOclqIN2L1WUfti38  2015-11-28T19:19:35Z  2018-09-10T21:06:16Z
#
#              address                                         categories  \
# 0  5921 Valencia Cir  Hotels,Hotels and motels,Hotel and motel reser...
# 1  5921 Valencia Cir  Hotels,Hotels and motels,Hotel and motel reser...
# 2  5921 Valencia Cir  Hotels,Hotels and motels,Hotel and motel reser...
# 3     7520 Teague Rd  Hotels,Hotels and motels,Travel agencies and b...
# 4     7520 Teague Rd  Hotels,Hotels and motels,Travel agencies and b...
#
#                primaryCategories             city country  \
# 0  Accommodation & Food Services  Rancho Santa Fe      US
# ...

# %%
df32 = df2[['reviews.rating', 'reviews.text']]

# %%
from sklearn.model_selection import train_test_split
df33, x_test, y_train, y_test = train_test_split(df32['reviews.text'], df32['reviews.rating'], random_state=1)

# %%
rate_list = []
math_list = []
actual_list = []

for x in range(len(df33)):
    splitter = df33.iloc[x].split()
#     print(splitter)
    senty = sentScore(splitter)
    if senty > 0:
        senty2 = 1
    elif senty < 0:
        senty2 = 0
    else:
        senty2 = 2
    #print(str(senty2) + ' Actual Rating:  ' + str(df33.iloc[x]['reviews.rating']))
    rate_list.append(senty2)
    math_list.append(senty)
    actual_list.append(df33.iloc[x])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-94dc645382c5> in <module>
#       4
#       5 for x in range(len(df33)):
# ----> 6     splitter = df33.iloc[x].split()
#       7 #     print(splitter)
#       8     senty = sentScore(splitter)
#
# AttributeError: 'float' object has no attribute 'split'

# %%
df44 = pd.DataFrame(data=rate_list)
df45 = pd.DataFrame(data=math_list)
df46 = pd.DataFrame(data=actual_list)

# %%
df77 = df44.join(df45, lsuffix='a')

# %%
df77 = df77.join(df46, rsuffix='b')

# %%
df77.set_axis(['Guess', 'Score', 'Rating'], axis=1, inplace=True)

# %%
df77
# Out:
#       Guess     Score                                             Rating
# 0         2  0.000000  Bad: We had the bad luck of staying in a room ...
# 1         1  0.104167  We have stayed at this motel many times while ...
# 2         1  0.064103  We traveled to Tarpon Springs for two reasons:...
# 3         1  0.033898  We arrived early and we hadn't slept. Our room...
# 4         1  0.013889  Not in the greatest area, but cant complain ab...
# ...     ...       ...                                                ...
# 3528      2  0.000000          Good: everithing beyond our expectations.
# 3529      1  0.032787  Might have stayed in a BW a handful of times o...
# 3530      1  0.026316  Barely a 4-star. Bathroom looked like somethin...
# 3531      0 -0.069767  Nice hotel and very nice staff. Big problem wi...
# 3532      1  0.008746  Today with the economy the way it is everyone ...
#
# [3533 rows x 3 columns]

# %%
df88 = df77.set_index('Guess')

# %%
poop = df77.groupby('Guess')

# %%
trueP = 0
falseP = 0
trueN = 0
falseN = 0
trueNu = 0
falsePNu = 0
falseNNu = 0
falseNuP = 0
falseNuN = 0

for x in range(len(df77)):
#     print(df77.iloc[x])
    if df77.iloc[x][0] == 1 and df77.iloc[x][2] >= 4:
        trueP += 1
    if df77.iloc[x][0] == 1 and df77.iloc[x][2] <= 2:
        falseP += 1
    if df77.iloc[x][0] == 1 and df77.iloc[x][2] < 4 and df77.iloc[x][2] > 2:
        falsePNu += 1
    if df77.iloc[x][0] == 0 and df77.iloc[x][2] >= 4:
        falseN += 1
    if df77.iloc[x][0] == 0 and df77.iloc[x][2] <= 2:
        trueN += 1
    if df77.iloc[x][0] == 0 and df77.iloc[x][2] < 4 and df77.iloc[x][2] > 2:
        falseNNu += 1
    if df77.iloc[x][0] == 2 and df77.iloc[x][2] < 4 and df77.iloc[x][2] > 2:
        trueNu += 1
    if df77.iloc[x][0] == 2 and df77.iloc[x][2] >= 4:
        falseNuP += 1
    if df77.iloc[x][0] == 2 and df77.iloc[x][2] <= 2:
        falseNuN += 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-cbca76a2b69a> in <module>
#      23     if df77.iloc[x][0] == 0 and df77.iloc[x][2] < 4 and df77.iloc[x][2] > 2:
#      24         falseNNu += 1
# ---> 25     if df77.iloc[x][0] == 2 and df77.iloc[x][2] < 4 and df77.iloc[x][2] > 2:
#      26         trueNu += 1
#      27     if df77.iloc[x][0] == 2 and df77.iloc[x][2] >= 4:
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
accur = (trueP + trueN + trueNu) / (trueP + trueN + trueNu + falseP + falsePNu + falseNuN + falseN + falseNNu + falseNuP)

# %%
print(accur)

# %%
confuM = [[trueP, falseP, falsePNu] , [falseN, trueN, falseNNu] , [falseNuN, falseNuP, trueNu]]

# %%
for x in confuM:
    print(x)
